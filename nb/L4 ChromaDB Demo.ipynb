# %%
import os
import chromadb
from chromadb.utils import embedding_functions
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain_core.documents import Document
import numpy as np

# %%
sentence_list = [
    "Meta drops multimodal Llama 3.2 — here's why it's such a big deal",
    "Chip giant Nvidia acquires OctoAI, a Seattle startup that helps companies run AI models",
    "Google is bringing Gemini to all older Pixel Buds",
    "The first Intel Battlmage GPU benchmarks have leaked",
    "Dell partners with Nvidia to accelerate AI adoption in telecoms",
]
ids = ["id1", "id2", "id3", "id4", "id5"]

# %% [markdown]
# **Creating a collection**

# %%
chroma_client = chromadb.Client()

# %%
# To persist in disk, use:
chroma_client = chromadb.PersistentClient(path="chromadb/")

# %%
collection = chroma_client.create_collection(name="udacity")

# %%
# By default, Chroma uses the Sentence Transformers all-MiniLM-L6-v2 
# model to create embeddings.
collection.add(
    documents=sentence_list,
    ids=ids
)
# Out:
# /Users/amundle/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:01<00:00, 52.1MiB/s]

# %%
collection._embedding_function

# %%
collection.count()
# Out:
# 5

# %%
collection.peek(2)
# Out:
# {'ids': ['id1', 'id2'],
#  'embeddings': array([[ 6.06655143e-02, -3.51322480e-02,  6.06437288e-02,
#          -5.11925854e-02,  1.13580197e-01, -1.88892763e-02,
#          -2.68528331e-02,  5.48633784e-02,  3.23644504e-02,
#           5.42442985e-02, -4.04198468e-02, -1.90558676e-02,
#          -5.97919673e-02,  2.56032404e-02,  8.48459899e-02,
#           4.12196927e-02,  3.95206176e-02, -4.00091521e-02,
#          -7.66606703e-02,  2.78292280e-02,  5.38355187e-02,
#          -1.35247353e-02,  9.65649709e-02, -3.04361507e-02,
#           6.61455886e-03,  7.21730739e-02, -9.53866169e-02,
#          -2.75959335e-02,  7.86793791e-03, -6.68519735e-02,
#          -1.27341859e-02,  1.21338010e-01, -6.66138083e-02,
#          -3.28670517e-02, -6.49284273e-02, -1.61901880e-02,
#          -3.32960160e-03,  8.04080665e-02, -3.84503491e-02,
#           1.37278825e-04,  3.72596853e-03,  4.83831167e-02,
#          -3.65696087e-06, -4.51370180e-02, -1.37449345e-02,
#          -7.15254620e-02,  1.01806317e-02, -4.23029736e-02,
#           3.16683613e-02,  1.55983986e-02, -3.97931077e-02,
#          -5.78960441e-02, -6.40795799e-03,  5.05231433e-02,
#           1.33638028e-02, -6.78852126e-02,  1.05864527e-02,
#          -4.71998043e-02,  2.75698840e-03,  6.26822039e-02,
#           3.98217663e-02,  2.90143117e-03, -1.10629899e-02,
#          -3.56735885e-02,  1.66206136e-01,  2.18522109e-05,
#          -9.47266445e-03, -1.11342639e-01,  2.20047049e-02,
#          -5.18189110e-02, -1.24161493e-03, -1.01766353e-02,
#           2.69737039e-02,  4.42355014e-02, -6.56566024e-02,
#           3.83598581e-02,  4.76824455e-02, -3.88536416e-02,
#           6.39469102e-02,  2.61559170e-02,  1.20892607e-01,
#          -9.07306932e-03, -3.85694169e-02,  2.28223912e-02,
#           5.07763820e-03, -1.89749748e-02, -2.87914295e-02,
#          -5.56396134e-02, -8.60800594e-03,  5.86411171e-03,
#           5.63661344e-02,  6.81668753e-03,  4.91599105e-02,
#           1.10514201e-01, -3.60370390e-02, -2.38150060e-02,
#          -4.80750203e-03,  8.54946149e-04, -2.90416796e-02,
#           5.46619706e-02,  6.12850115e-02,  6.83306679e-02,
#           3.28914286e-03, -1.86500512e-02,  2.17972836e-03,
#          -2.47970447e-02,  3.17366086e-02, -4.79939468e-02,
#          -5.55192791e-02,  1.94785595e-02,  5.60776852e-02,
#          -2.32826397e-02, -2.67986413e-02, -1.99877005e-02,
#          -6.67306408e-03, -5.98347150e-02, -5.08502275e-02,
#           3.77212651e-02, -1.08493462e-01, -5.01809753e-02,
#          -1.64725129e-02, -4.65889014e-02,  4.81395759e-02,
#           1.10929832e-03, -3.84517089e-02, -8.76592919e-02,
#           1.10432729e-01,  1.17870227e-01,  7.98041373e-02,
#          -6.53523859e-03,  8.27739835e-02,  5.29982941e-03,
#          -6.89221220e-03,  1.71752460e-02, -9.60678905e-02,
#           6.84440359e-02, -3.43733393e-02,  4.36990112e-02,
#          -7.35757127e-02, -2.06464978e-08,  6.44843802e-02,
#          -8.62903967e-02,  4.45740595e-02,  7.28146285e-02,
#           2.51241196e-02, -2.80442685e-02, -1.90443248e-02,
#           7.25760609e-02,  1.85971726e-02, -3.86337638e-02,
#           4.14177887e-02, -3.46551016e-02, -1.12843234e-02,
#           9.12684668e-03,  2.32852269e-02,  6.44715875e-02,
#           3.40284109e-02,  5.41293211e-02,  1.49638141e-02,
#          -2.31917650e-02, -7.17393905e-02,  3.89346331e-02,
#           5.01998439e-02, -4.37411591e-02, -4.84554796e-03,
#           2.66040966e-04,  6.21850044e-02, -2.18042918e-02,
#          -2.09653098e-02,  4.76173982e-02, -2.41803918e-02,
#           9.00905803e-02,  7.04801902e-02, -1.68023594e-02,
#           3.73757444e-02, -2.76611354e-02,  4.38806191e-02,
#           5.74536845e-02,  5.67062497e-02, -7.83978626e-02,
#           2.85955369e-02,  6.44664317e-02, -2.42865160e-02,
#          -3.25283818e-02,  7.15361685e-02,  1.76961161e-02,
#          -4.51462194e-02, -1.30367711e-01,  4.10726331e-02,
#           1.98864285e-02, -4.21720482e-02,  3.79164293e-02,
#          -3.52896713e-02,  9.15217772e-02, -2.44520288e-02,
#          -3.62964161e-02, -1.01935916e-01, -9.57374573e-02,
#          -3.20857093e-02,  5.41213751e-02,  1.11661805e-02,
#          -4.48201336e-02,  9.90404636e-02, -1.78611763e-02]]),
#  'documents': ["Meta drops multimodal Llama 3.2 — here's why it's such a big deal",
#   'Chip giant Nvidia acquires OctoAI, a Seattle startup that helps companies run AI models'],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'embeddings'],
#  'data': None,
#  'metadatas': [None, None]}

# %%
collection.query(
    query_texts=["gadget"],
    n_results=2,
    include=['metadatas', 'documents', 'distances']
)
# Out:
# {'ids': [['id3', 'id1']],
#  'embeddings': None,
#  'documents': [['Google is bringing Gemini to all older Pixel Buds',
#    "Meta drops multimodal Llama 3.2 — here's why it's such a big deal"]],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.5251753330230713, 1.7548508644104004]]}

# %% [markdown]
# **Choosing other models**

# %%
embeddings_fn = embedding_functions.SentenceTransformerEmbeddingFunction(
    model_name="all-mpnet-base-v2"
)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
embeddings = embeddings_fn(sentence_list)
len(embeddings)
# Out:
# 5

# %%
print(np.dot(embeddings[1], embeddings[4]))
print(sentence_list[1])
print(sentence_list[4])
# Out:
# 0.5583155
# Chip giant Nvidia acquires OctoAI, a Seattle startup that helps companies run AI models
# Dell partners with Nvidia to accelerate AI adoption in telecoms

# %%
from dotenv import load_dotenv
load_dotenv()

embeddings_fn = embedding_functions.OpenAIEmbeddingFunction(
    api_key=os.getenv("VOCAREUM_OPENAI_API_KEY"),
    api_base="https://openai.vocareum.com/v1",
    model_name="text-embedding-ada-002"
)

# %%
# Print all attributes to find the right one
for attr in dir(embeddings_fn):
    if 'model' in attr.lower():
        print(f"{attr}: {getattr(embeddings_fn, attr, 'N/A')}")
# Out:
# model_name: text-embedding-ada-002

# %%
embeddings_fn.model_name
# Out:
# 'text-embedding-ada-002'

# %%
chroma_client.delete_collection(name="udacity")

collection = chroma_client.create_collection(
    name="udacity",
    embedding_function=embeddings_fn
)

# %%
collection.add(
    documents=sentence_list,
    ids=ids
)

# %%
collection._embedding_function

# %%
collection.query(
    query_texts=["gadget"],
    n_results=2,
    include=['metadatas', 'documents', 'distances']
)
# Out:
# {'ids': [['id3', 'id4']],
#  'embeddings': None,
#  'documents': [['Google is bringing Gemini to all older Pixel Buds',
#    'The first Intel Battlmage GPU benchmarks have leaked']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[0.46601054072380066, 0.48678600788116455]]}

# %% [markdown]
# **Using with LangChain**

# %%
chroma_client.delete_collection(name="udacity")

# %%
from dotenv import load_dotenv
load_dotenv()

vector_store = Chroma(
    collection_name="udacity",
    embedding_function=OpenAIEmbeddings(
        api_key=os.getenv("VOCAREUM_OPENAI_API_KEY"),
        base_url="https://openai.vocareum.com/v1",
        model="text-embedding-ada-002"
        # api_base="https://openai.vocareum.com/v1",
        # model_name="text-embedding-ada-002" 
    ),
)

# %%
documents = [
    Document(
        page_content="Meta drops multimodal Llama 3.2 — here's why it's such a big deal",
        metadata={"company":"Meta", "topic": "llama"}
    ),
    Document(
        page_content="Chip giant Nvidia acquires OctoAI, a Seattle startup that helps companies run AI models",
        metadata={"company":"Nvidia", "topic": "acquisition"}
    ),
    Document(
        page_content="Google is bringing Gemini to all older Pixel Buds",
        metadata={"company":"Google", "topic": "gemini"}
    ),
    Document(
        page_content="The first Intel Battlmage GPU benchmarks have leaked",
        metadata={"company":"Intel", "topic": "gpu"}
    ),
    Document(
        page_content="Dell partners with Nvidia to accelerate AI adoption in telecoms",
        metadata={"company":"Dell", "topic": "partnership"}
    ),
]

# %%
vector_store.add_documents(documents=documents, ids=ids)
# Out:
# ['id1', 'id2', 'id3', 'id4', 'id5']

# %%
results = vector_store.similarity_search_with_score(query="gpu",k=2)
for doc, score in results:
    print(f"-> {doc.page_content}\n   [Score={score:.2f}]\n   [{doc.metadata}]\n\n")
# Out:
# -> The first Intel Battlmage GPU benchmarks have leaked
#    [Score=0.35]
#    [{'topic': 'gpu', 'company': 'Intel'}]
#
#
# -> Chip giant Nvidia acquires OctoAI, a Seattle startup that helps companies run AI models
#    [Score=0.41]
#    [{'company': 'Nvidia', 'topic': 'acquisition'}]
